# %% [markdown]
# - [список доступов](https://docs.google.com/spreadsheets/d/1VrBRLNX-cEWHrMiVY9DWvy3n6Ne8GXID7DJsKh8dhmc/edit#gid=0)
# -
# - метро комсомольская бауманская метро
#
# - Ул. Ольховская 4к2
# - Еще раз, напомню. Сегодня лекция в Альфа-лабе, по адрессу - Ул Ольховская 4к2, Бизнес-центр Мельников, 3 этаж. С собой объязательно нажно иметь паспорт.
# - Ищите табличку “На работу с радостью”

# %% [markdown]
# - Архитектура

# %% [markdown]
# ![image.png](attachment:image.png)
