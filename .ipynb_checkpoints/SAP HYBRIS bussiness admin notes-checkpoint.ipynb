# %% [markdown]
# #
#
# - Search in Jira
#     project = GJHYBRIS AND issuetype = "Action item" AND due <2018-04-04 AND status !=Closed

# %% [markdown]
# - configuring url
# ![image.png](attachment:image.png)

# %% [markdown]
# # Links
#
# - https://localhost:9002/p/4680434560859 by product
# - https://localhost:9002/?site=gj-site

# %% [markdown]
# ![image.png](attachment:image.png)
