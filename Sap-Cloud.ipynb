# %% [markdown]
# # Sap cloud
# - [Cloud Services Description V3.0](docs/SAP Hybris Commerce Cloud_Services Description_v3.0.pdf)
# - [Cloud Services Description V3.3](docs/SAP Hybris Commerce Cloud_Services Description_v3.3.pdf)
#
# - [Gloria Jeans GLJ Kick-off meeting](docs/Gloria Jeans GLJ Kick-off meeting.pdf)
#
#
# - [Package Contents v2.3.3](https://help.hybris.com/6.6.0/hcd/691db27e7fee481aa62c563f1b7f721e.html#loio691db27e7fee481aa62c563f1b7f721e)
# - [Deployment Request Form - v3.0 for Deployment Packaging Spec v2.3](https://wiki.hybris.com/display/SUP/Deployment+Request+Form+-+v3.0+for+Deployment+Packaging+Spec+v2.3)

# %% [markdown]
# - [Cloud Services](https://wiki.hybris.com/pages/viewpage.action?spaceKey=SUP&title=Cloud+Services)
#     - [How to raise an incident](https://wiki.hybris.com/display/SUP/How+to+Raise+an+Incident+for+SAP+Hybris+Cloud+Service+at+SAP+Support+Portal)
#     - [How to Request a Service on the SAP Support Portal](https://wiki.hybris.com/display/SUP/How+to+Request+a+Service+on+the+SAP+Support+Portal)

# %% [markdown]
# fill deployment form
# upload necessary files
# create incident

# %% [markdown]
# # Dev

# %% [markdown]
# # QA

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -[qa network diagram](docs/GLORIA_JEANSGLORIA_JEANS1ng.pdf)

# %% [markdown]
#  deployment to Staging
#
# As far as i could get, the steps are:
#
# - upload file to /NFS_DATA/deployment/
# - prepare Deployment Request Form file
# - raise the deployment incident through SAP Portal Using S-User, and attaching DRF file
#
# should we use S-User of Customer, or Partner S-User will do ad well?

# %% [markdown]
# - /NFS_DATA/deployment у всех сред разный или одинаковый?
